# %% [markdown]
# ![alt text](https://drive.google.com/uc?export=view&id=1UXScsVx_Wni_JuDdB8LeTnM6jsPfIwkW)
#
# Proprietary content. © Great Learning. All Rights Reserved. Unauthorized use or distribution prohibited.

# %% [markdown]
# # Instructions
# - Some parts of the code are already done for you
# - You need to execute all the cells
# - You need to add the code where ever you see `"#### Add your code here ####"`
# - Marks are mentioned along with the cells

# %% [markdown]
# # Face recognition
# Task is to recognize a faces

# %% [markdown]
# ### Dataset
# **Aligned Face Dataset from Pinterest**
#
# This dataset contains 10.770 images for 100 people. All images are taken from 'Pinterest' and      aligned using dlib library.

# %%
import tensorflow
tensorflow.__version__
# Out:
# '2.3.0'

# %% [markdown]
# #### Mount Google drive if you are using google colab
# - We recommend using Google Colab as you can face memory issues and longer runtimes while running on local

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #### Change current working directory to project folder (2 marks)

# %%
import numpy as np

project_path = '/content/drive/My Drive/ColabNotebooks/'

# %% [markdown]
# ### Extract the zip file (3 marks)
# - Extract Aligned Face Dataset from Pinterest.zip

# %%
images_zip_path = project_path + "Pinterest.zip"

from zipfile import ZipFile

with ZipFile(images_zip_path, 'r') as z:
  z.extractall()

# %%
ls
# Out:
# drive/  pins/  PINS/  sample_data/

# %% [markdown]
# ### Function to load images
# - Define a function to load the images from the extracted folder and map each image with person id

# %%
import numpy as np
import os

class IdentityMetadata():
    def __init__(self, base, name, file):
        # print(base, name, file)
        # dataset base directory
        self.base = base
        # identity name
        self.name = name
        # image file name
        self.file = file

    def __repr__(self):
        return self.image_path()

    def image_path(self):
        return os.path.join(self.base, self.name, self.file) 
    
def load_metadata(path):
    metadata = []
    for i in os.listdir(path):
        for f in os.listdir(os.path.join(path, i)):
            # Check file extension. Allow only jpg/jpeg' files.
            ext = os.path.splitext(f)[1]
            if ext == '.jpg' or ext == '.jpeg':
                metadata.append(IdentityMetadata(path, i, f))
    return np.array(metadata)

# metadata = load_metadata('images')
metadata = load_metadata('PINS')

# %% [markdown]
# ### Define function to load image
# - Define a function to load image from the metadata

# %%
import cv2
def load_image(path):
    img = cv2.imread(path, 1)
    # OpenCV loads images with color channels
    # in BGR order. So we need to reverse them
    return img[...,::-1]

# %% [markdown]
# #### Load a sample image (3 marks)
# - Load one image using the function "load_image"

# %%
import matplotlib.pyplot as plt
img_path = metadata[34].image_path()
img = load_image(img_path)
print(plt.imshow(img))
# Out:
# AxesImage(54,36;334.8x217.44)

# %% [markdown]
# ### VGG Face model
# - Here we are giving you the predefined model for VGG face

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import ZeroPadding2D, Convolution2D, MaxPooling2D, Dropout, Flatten, Activation

def vgg_face():	
    model = Sequential()
    model.add(ZeroPadding2D((1,1),input_shape=(224,224, 3)))
    model.add(Convolution2D(64, (3, 3), activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))
    
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(128, (3, 3), activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(128, (3, 3), activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))
    
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(256, (3, 3), activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(256, (3, 3), activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(256, (3, 3), activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))
    
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, (3, 3), activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, (3, 3), activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, (3, 3), activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))
    
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, (3, 3), activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, (3, 3), activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, (3, 3), activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))
    
    model.add(Convolution2D(4096, (7, 7), activation='relu'))
    model.add(Dropout(0.5))
    model.add(Convolution2D(4096, (1, 1), activation='relu'))
    model.add(Dropout(0.5))
    model.add(Convolution2D(2622, (1, 1)))
    model.add(Flatten())
    model.add(Activation('softmax'))
    return model

# %% [markdown]
# #### Load the model (3 marks)
# - Load the model defined above
# - Then load the given weight file named "vgg_face_weights.h5"

# %%
model = vgg_face()
import h5py

weights_path = project_path+ 'vgg_face_weights.h5'

model.load_weights(weights_path)

# %% [markdown]
# ### Get vgg_face_descriptor

# %%
from tensorflow.keras.models import Model
vgg_face_descriptor = Model(inputs=model.layers[0].input, outputs=model.layers[-2].output)

# %% [markdown]
# ### Generate embeddings for each image in the dataset
# - Given below is an example to load the first image in the metadata and get its embedding vector from the pre-trained model.

# %%
# Get embedding vector for first image in the metadata using the pre-trained model

img_path = metadata[0].image_path()
img = load_image(img_path)

# Normalising pixel values from [0-255] to [0-1]: scale RGB values to interval [0,1]
img = (img / 255.).astype(np.float32)

img = cv2.resize(img, dsize = (224,224))
print(img.shape)

# Obtain embedding vector for an image
# Get the embedding vector for the above image using vgg_face_descriptor model and print the shape 

embedding_vector = vgg_face_descriptor.predict(np.expand_dims(img, axis=0))[0]
print(embedding_vector.shape)
# Out:
# (224, 224, 3)
# (2622,)

# %% [markdown]
# ### Generate embeddings for all images (8 marks)
# - Write code to iterate through metadata and create embeddings for each image using `vgg_face_descriptor.predict()` and store in a list with name `embeddings`
#
# - If there is any error in reading any image in the dataset, fill the emebdding vector of that image with 2622-zeroes as the final embedding from the model is of length 2622.

# %%
embeddings = np.zeros((metadata.shape[0], 2622))

for i, m in enumerate(metadata):
    img_path = metadata[i].image_path()
    img = load_image(img_path)
    img = (img / 255.).astype(np.float32)
    img = cv2.resize(img, dsize = (224,224))
    print(i,m)
    embeddings[i] = vgg_face_descriptor.predict(np.expand_dims(img, axis=0))[0]
# Out:
# Streaming output truncated to the last 5000 lines.
# 5770 PINS/pins_bill gates/bill gates47.jpg
# 5771 PINS/pins_Mike Colter/Mike Colter174_1341.jpg
# 5772 PINS/pins_Mike Colter/Mike Colter155_1335.jpg
# 5773 PINS/pins_Mike Colter/Mike Colter26_1305.jpg
# 5774 PINS/pins_Mike Colter/Mike Colter55_1279.jpg
# 5775 PINS/pins_Mike Colter/Mike Colter17_1340.jpg
# 5776 PINS/pins_Mike Colter/Mike Colter19_1334.jpg
# 5777 PINS/pins_Mike Colter/Mike Colter82_1339.jpg
# 5778 PINS/pins_Mike Colter/Mike Colter167_1342.jpg
# 5779 PINS/pins_Mike Colter/Mike Colter102_1332.jpg
# 5780 PINS/pins_Mike Colter/Mike Colter137_1277.jpg
# 5781 PINS/pins_Mike Colter/Mike Colter44_1303.jpg
# 5782 PINS/pins_Mike Colter/Mike Colter10_1308.jpg
# 5783 PINS/pins_Mike Colter/Mike Colter165_1300.jpg
# 5784 PINS/pins_Mike Colter/Mike Colter163_1296.jpg
# 5785 PINS/pins_Mike Colter/Mike Colter27_1322.jpg
# 5786 PINS/pins_Mike Colter/Mike Colter111_1294.jpg
# 5787 PINS/pins_Mike Colter/Mike Colter14_1283.jpg
# 5788 PINS/pins_Mike Colter/Mike Colter133_1327.jpg
# 5789 PINS/pins_Mike Colter/Mike Colter127_1302.jpg
# 5790 PINS/pins_Mike Colter/Mike Colter97_1276.jpg
# 5791 PINS/pins_Mike Colter/Mike Colter7_1323.jpg
# 5792 PINS/pins_Mike Colter/Mike Colter176_1325.jpg
# 5793 PINS/pins_Mike Colter/Mike Colter42_1288.jpg
# 5794 PINS/pins_Mike Colter/Mike Colter158_1324.jpg
# 5795 PINS/pins_Mike Colter/Mike Colter13_1278.jpg
# 5796 PINS/pins_Mike Colter/Mike Colter150_1330.jpg
# 5797 PINS/pins_Mike Colter/Mike Colter15_1304.jpg
# 5798 PINS/pins_Mike Colter/Mike Colter58_1336.jpg
# 5799 PINS/pins_Mike Colter/Mike Colter77_1320.jpg
# 5800 PINS/pins_Mike Colter/Mike Colter16_1273.jpg
# 5801 PINS/pins_Mike Colter/Mike Colter32_1275.jpg
# 5802 PINS/pins_Mike Colter/Mike Colter94_1309.jpg
# 5803 PINS/pins_Mike Colter/Mike Colter36_1272.jpg
# 5804 PINS/pins_Mike Colter/Mike Colter56_1301.jpg
# 5805 PINS/pins_Mike Colter/Mike Colter124_1313.jpg
# 5806 PINS/pins_Mike Colter/Mike Colter31_1306.jpg
# 5807 PINS/pins_Mike Colter/Mike Colter62_1285.jpg
# 5808 PINS/pins_Mike Colter/Mike Colter88_1297.jpg
# 5809 PINS/pins_Mike Colter/Mike Colter49_1316.jpg
# 5810 PINS/pins_Mike Colter/Mike Colter181_1291.jpg
# 5811 PINS/pins_Mike Colter/Mike Colter83_1298.jpg
# 5812 PINS/pins_Mike Colter/Mike Colter132_1290.jpg
# 5813 PINS/pins_Mike Colter/Mike Colter12_1312.jpg
# 5814 PINS/pins_Mike Colter/Mike Colter157_1287.jpg
# 5815 PINS/pins_Mike Colter/Mike Colter18_1289.jpg
# 5816 PINS/pins_Mike Colter/Mike Colter73_1319.jpg
# 5817 PINS/pins_Mike Colter/Mike Colter119_1338.jpg
# 5818 PINS/pins_Mike Colter/Mike Colter37_1284.jpg
# 5819 PINS/pins_Mike Colter/Mike Colter128_1299.jpg
# 5820 PINS/pins_Mike Colter/Mike Colter123_1317.jpg
# 5821 PINS/pins_Mike Colter/Mike Colter53_1286.jpg
# 5822 PINS/pins_Mike Colter/Mike Colter129_1314.jpg
# 5823 PINS/pins_Mike Colter/Mike Colter30_1311.jpg
# 5824 PINS/pins_Mike Colter/Mike Colter113_1295.jpg
# 5825 PINS/pins_Mike Colter/Mike Colter34_1321.jpg
# 5826 PINS/pins_Mike Colter/Mike Colter115_1310.jpg
# 5827 PINS/pins_Mike Colter/Mike Colter87_1329.jpg
# 5828 PINS/pins_Mike Colter/Mike Colter28_1333.jpg
# 5829 PINS/pins_Mike Colter/Mike Colter5_1315.jpg
# 5830 PINS/pins_Mike Colter/Mike Colter45_1274.jpg
# 5831 PINS/pins_Mike Colter/Mike Colter153_1292.jpg
# 5832 PINS/pins_Mike Colter/Mike Colter38_1281.jpg
# 5833 PINS/pins_Mike Colter/Mike Colter11_1293.jpg
# 5834 PINS/pins_Mike Colter/Mike Colter1_1318.jpg
# 5835 PINS/pins_Mike Colter/Mike Colter138_1337.jpg
# 6035 PINS/pins_alexandra daddario/alexandra daddario57.jpg
# 6036 PINS/pins_alexandra daddario/alexandra daddario68.jpg
# 6037 PINS/pins_alexandra daddario/alexandra daddario114.jpg
# 6038 PINS/pins_alexandra daddario/alexandra daddario132.jpg
# 6039 PINS/pins_alexandra daddario/alexandra daddario151.jpg
# 6040 PINS/pins_alexandra daddario/alexandra daddario88.jpg
# 6041 PINS/pins_alexandra daddario/alexandra daddario52.jpg
# 6042 PINS/pins_alexandra daddario/alexandra daddario21.jpg
# 6043 PINS/pins_alexandra daddario/alexandra daddario77.jpg
# 6044 PINS/pins_alexandra daddario/alexandra daddario165.jpg
# 6045 PINS/pins_alexandra daddario/alexandra daddario99.jpg
# 6046 PINS/pins_alexandra daddario/alexandra daddario96.jpg
# 6047 PINS/pins_alexandra daddario/alexandra daddario120.jpg
# 6048 PINS/pins_alexandra daddario/alexandra daddario117.jpg
# 6049 PINS/pins_alexandra daddario/alexandra daddario89.jpg
# 6050 PINS/pins_alexandra daddario/alexandra daddario12.jpg
# 6051 PINS/pins_alexandra daddario/alexandra daddario128.jpg
# 6052 PINS/pins_alexandra daddario/alexandra daddario149.jpg
# 6053 PINS/pins_alexandra daddario/alexandra daddario79.jpg
# 6054 PINS/pins_alexandra daddario/alexandra daddario134.jpg
# 6055 PINS/pins_alexandra daddario/alexandra daddario150.jpg
# 6056 PINS/pins_alexandra daddario/alexandra daddario55.jpg
# 6057 PINS/pins_alexandra daddario/alexandra daddario125.jpg
# 6058 PINS/pins_alexandra daddario/alexandra daddario31.jpg
# 6059 PINS/pins_alexandra daddario/alexandra daddario5.jpg
# 6060 PINS/pins_alexandra daddario/alexandra daddario140.jpg
# 6061 PINS/pins_alexandra daddario/alexandra daddario155.jpg
# 6062 PINS/pins_alexandra daddario/alexandra daddario47.jpg
# 6063 PINS/pins_alexandra daddario/alexandra daddario97.jpg
# 6064 PINS/pins_alexandra daddario/alexandra daddario34.jpg
# 6065 PINS/pins_alexandra daddario/alexandra daddario164.jpg
# 6066 PINS/pins_alexandra daddario/alexandra daddario113.jpg
# 6067 PINS/pins_alexandra daddario/alexandra daddario98.jpg
# 6068 PINS/pins_alexandra daddario/alexandra daddario58.jpg
# 6069 PINS/pins_alexandra daddario/alexandra daddario84.jpg
# 6070 PINS/pins_alexandra daddario/alexandra daddario122.jpg
# 6071 PINS/pins_alexandra daddario/alexandra daddario10.jpg
# 6072 PINS/pins_alexandra daddario/alexandra daddario61.jpg
# 6073 PINS/pins_alexandra daddario/alexandra daddario67.jpg
# 6074 PINS/pins_alexandra daddario/alexandra daddario141.jpg
# 6075 PINS/pins_alexandra daddario/alexandra daddario111.jpg
# 6076 PINS/pins_alexandra daddario/alexandra daddario40.jpg
# 6077 PINS/pins_alexandra daddario/alexandra daddario53.jpg
# 6078 PINS/pins_alexandra daddario/alexandra daddario161.jpg
# 6079 PINS/pins_alexandra daddario/alexandra daddario9.jpg
# 6080 PINS/pins_alexandra daddario/alexandra daddario62.jpg
# 6173 PINS/pins_alexandra daddario/alexandra daddario4.jpg
# 6174 PINS/pins_alexandra daddario/alexandra daddario81.jpg
# 6175 PINS/pins_alexandra daddario/alexandra daddario92.jpg
# 6176 PINS/pins_alexandra daddario/alexandra daddario22.jpg
# 6177 PINS/pins_alexandra daddario/alexandra daddario100.jpg
# 6178 PINS/pins_alexandra daddario/alexandra daddario49.jpg
# 6179 PINS/pins_alexandra daddario/alexandra daddario90.jpg
# 6180 PINS/pins_alexandra daddario/alexandra daddario65.jpg
# 6181 PINS/pins_alexandra daddario/alexandra daddario2.jpg
# 6182 PINS/pins_alexandra daddario/alexandra daddario123.jpg
# 6183 PINS/pins_alexandra daddario/alexandra daddario157.jpg
# 6184 PINS/pins_alexandra daddario/alexandra daddario93.jpg
# 6185 PINS/pins_alexandra daddario/alexandra daddario33.jpg
# 6186 PINS/pins_alexandra daddario/alexandra daddario26.jpg
# 6187 PINS/pins_alexandra daddario/alexandra daddario133.jpg
# 6188 PINS/pins_alexandra daddario/alexandra daddario78.jpg
# 6189 PINS/pins_alexandra daddario/alexandra daddario30.jpg
# 6190 PINS/pins_alexandra daddario/alexandra daddario166.jpg
# 6191 PINS/pins_alexandra daddario/alexandra daddario41.jpg
# 6192 PINS/pins_alexandra daddario/alexandra daddario95.jpg
# 6193 PINS/pins_alexandra daddario/alexandra daddario142.jpg
# 6194 PINS/pins_alexandra daddario/alexandra daddario163.jpg
# 6195 PINS/pins_alexandra daddario/alexandra daddario51.jpg
# 6196 PINS/pins_alexandra daddario/alexandra daddario129.jpg
# 6197 PINS/pins_alexandra daddario/alexandra daddario112.jpg
# 6198 PINS/pins_alexandra daddario/alexandra daddario154.jpg
# 6199 PINS/pins_Chris Evans/Chris Evans61.jpg
# 6200 PINS/pins_Chris Evans/Chris Evans47.jpg
# 6201 PINS/pins_Chris Evans/Chris Evans63.jpg
# 6202 PINS/pins_Chris Evans/Chris Evans60.jpg
# 6203 PINS/pins_Chris Evans/Chris Evans29.jpg
# 6204 PINS/pins_Chris Evans/Chris Evans15.jpg
# 6205 PINS/pins_Chris Evans/Chris Evans86.jpg
# 6206 PINS/pins_Chris Evans/Chris Evans30.jpg
# 6207 PINS/pins_Chris Evans/Chris Evans50.jpg
# 6208 PINS/pins_Chris Evans/Chris Evans72.jpg
# 6209 PINS/pins_Chris Evans/Chris Evans3.jpg
# 6210 PINS/pins_Chris Evans/Chris Evans9.jpg
# 6211 PINS/pins_Chris Evans/Chris Evans75.jpg
# 6212 PINS/pins_Chris Evans/Chris Evans66.jpg
# 6213 PINS/pins_Chris Evans/Chris Evans1.jpg
# 6214 PINS/pins_Chris Evans/Chris Evans70.jpg
# 6215 PINS/pins_Chris Evans/Chris Evans26.jpg
# 6216 PINS/pins_Chris Evans/Chris Evans28.jpg
# 6217 PINS/pins_Chris Evans/Chris Evans24.jpg
# 6218 PINS/pins_Chris Evans/Chris Evans56.jpg
# 6219 PINS/pins_Chris Evans/Chris Evans39.jpg
# 10726 PINS/pins_shakira/shakira9.jpg
# 10727 PINS/pins_shakira/shakira33.jpg
# 10728 PINS/pins_shakira/shakira32.jpg
# 10729 PINS/pins_shakira/shakira44.jpg
# 10730 PINS/pins_shakira/shakira42.jpg
# 10731 PINS/pins_shakira/shakira10.jpg
# 10732 PINS/pins_shakira/shakira23.jpg
# 10733 PINS/pins_shakira/shakira45.jpg
# 10734 PINS/pins_shakira/shakira38.jpg
# 10735 PINS/pins_shakira/shakira17.jpg
# 10736 PINS/pins_shakira/shakira7.jpg
# 10737 PINS/pins_shakira/shakira46.jpg
# 10738 PINS/pins_shakira/shakira18.jpg
# 10739 PINS/pins_shakira/shakira8.jpg
# 10740 PINS/pins_shakira/shakira27.jpg
# 10741 PINS/pins_shakira/shakira11.jpg
# 10742 PINS/pins_shakira/shakira41.jpg
# 10743 PINS/pins_shakira/shakira35.jpg
# 10744 PINS/pins_shakira/shakira12.jpg
# 10745 PINS/pins_shakira/shakira28.jpg
# 10746 PINS/pins_shakira/shakira26.jpg
# 10747 PINS/pins_shakira/shakira34.jpg
# 10748 PINS/pins_shakira/shakira47.jpg
# 10749 PINS/pins_shakira/shakira25.jpg
# 10750 PINS/pins_shakira/shakira36.jpg
# 10751 PINS/pins_shakira/shakira15.jpg
# 10752 PINS/pins_shakira/shakira31.jpg
# 10753 PINS/pins_shakira/shakira21.jpg
# 10754 PINS/pins_shakira/shakira14.jpg
# 10755 PINS/pins_shakira/shakira49.jpg
# 10756 PINS/pins_shakira/shakira20.jpg
# 10757 PINS/pins_shakira/shakira1.jpg
# 10758 PINS/pins_shakira/shakira22.jpg
# 10759 PINS/pins_shakira/shakira40.jpg
# 10760 PINS/pins_shakira/shakira29.jpg
# 10761 PINS/pins_shakira/shakira5.jpg
# 10762 PINS/pins_shakira/shakira43.jpg
# 10763 PINS/pins_shakira/shakira24.jpg
# 10764 PINS/pins_shakira/shakira3.jpg
# 10765 PINS/pins_shakira/shakira16.jpg
# 10766 PINS/pins_shakira/shakira19.jpg
# 10767 PINS/pins_shakira/shakira4.jpg
# 10768 PINS/pins_shakira/shakira48.jpg
# 10769 PINS/pins_shakira/shakira6.jpg

# %% [markdown]
# ### Function to calculate distance between given 2 pairs of images.
#
# - Consider distance metric as "Squared L2 distance"
# - Squared l2 distance between 2 points (x1, y1) and (x2, y2) = (x1-x2)^2 + (y1-y2)^2

# %%
def distance(emb1, emb2):
    return np.sum(np.square(emb1 - emb2))

# %% [markdown]
# #### Plot images and get distance between the pairs given below
# - 2, 3 and 2, 180
# - 30, 31 and 30, 100
# - 70, 72 and 70, 115

# %%
import matplotlib.pyplot as plt

def show_pair(idx1, idx2):
    plt.figure(figsize=(8,3))
    plt.suptitle(f'Distance = {distance(embeddings[idx1], embeddings[idx2]):.2f}')
    plt.subplot(121)
    plt.imshow(load_image(metadata[idx1].image_path()))
    plt.subplot(122)
    plt.imshow(load_image(metadata[idx2].image_path()));    

show_pair(2, 3)
show_pair(2, 180)

# %% [markdown]
# ### Create train and test sets (8 marks)
# - Create X_train, X_test and y_train, y_test
# - Use train_idx to seperate out training features and labels
# - Use test_idx to seperate out testing features and labels

# %%
train_idx = np.arange(metadata.shape[0]) % 9 != 0     #every 9th example goes in test data and rest go in train data
test_idx = np.arange(metadata.shape[0]) % 9 == 0

# one half as train examples of 10 identities
X_train = embeddings[train_idx]
# another half as test examples of 10 identities

X_test=embeddings[test_idx]

targets = np.array([m.name for m in metadata])
#train labels
y_train = targets[train_idx]
#test labels
y_test=targets[test_idx]

# %% [markdown]
# ### Encode the Labels (4 marks)
# - Encode the targets
# - Use LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder

# label_encoder object knows how to understand word labels. 
label_encoder = LabelEncoder() 

 
label_encoder.fit(targets)
y = label_encoder.transform(targets)

y_train = y[train_idx]
y_test = y[test_idx]

# %% [markdown]
# ### Standardize the feature values (4 marks)
# - Scale the features using StandardScaler

# %%
# Standarize features
from sklearn.preprocessing import StandardScaler

sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.fit_transform(X_test)

# %% [markdown]
# ### Reduce dimensions using PCA (4 marks)
# - Reduce feature dimensions using Principal Component Analysis
# - Set the parameter n_components=128

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=128)
X_train = pca.fit_transform(X_train)
X_test = pca.fit_transform(X_test)

explained_variance = pca.explained_variance_ratio_

# %% [markdown]
# ### Build a Classifier (4 marks)
# - Use SVM Classifier to predict the person in the given image
# - Fit the classifier and print the score

# %%
from sklearn.svm import SVC
from sklearn.metrics import f1_score, accuracy_score

clf = SVC(kernel='linear') # Linear Kernel

#Train the model using the training sets
clf.fit(X_train, y_train)

#Predict the response for test dataset
acc_svc = accuracy_score(y_test, clf.predict(X_test))
print(acc_svc)
# Out:
# 0.061821219715956555

# %% [markdown]
# ### Test results (2 mark)
# - Take 10th image from test set and plot the image
# - Report to which person(folder name in dataset) the image belongs to

# %%
import warnings
# Suppress LabelEncoder warning
warnings.filterwarnings('ignore')

example_idx = 10

example_image = load_image(metadata[test_idx][example_idx].image_path())
example_prediction = clf.predict([embeddings[test_idx][example_idx]])
example_identity = label_encoder.inverse_transform(example_prediction)[0]

plt.imshow(example_image)
plt.title(f'Identified as {example_identity}');
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-101-7376587a6b65> in <module>()
#       6
#       7 example_image = load_image(metadata[test_idx][example_idx].image_path())
# ----> 8 example_prediction = clf.predict([embeddings[test_idx][example_idx]])
#       9 example_identity = label_encoder.inverse_transform(example_prediction)[0]
#      10
#
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/_base.py in predict(self, X)
#     592             y = np.argmax(self.decision_function(X), axis=1)
#     593         else:
# --> 594             y = super().predict(X)
#     595         return self.classes_.take(np.asarray(y, dtype=np.intp))
#     596
#
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/_base.py in predict(self, X)
#     313         y_pred : array, shape (n_samples,)
#     314         """
# --> 315         X = self._validate_for_predict(X)
#     316         predict = self._sparse_predict if self._sparse else self._dense_predict
#     317         return predict(X)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/_base.py in _validate_for_predict(self, X)
#     465             raise ValueError("X.shape[1] = %d should be equal to %d, "
#     466                              "the number of features at training time" %
# --> 467                              (n_features, self.shape_fit_[1]))
#     468         return X
#     469
#
# ValueError: X.shape[1] = 2622 should be equal to 128, the number of features at training time
